# %%
import pandas as pd
import numpy as np
from functools import reduce
from pathlib import Path
import os
import sys
import csv

pd.set_option('display.max_columns', None)
rootdir = os.path.join(os.path.abspath(''), 'Assignment2_Company_ETL')

# %%
# collect dataframes from files
df_list = []
for root, dirs, files in os.walk(rootdir):
    for file in files:
        if file.endswith('.xlsx'):
            # extract file from each file path found by os.walk()
            df = pd.read_excel(os.path.join(root, file), ignore_index=True)
            
            # attach month & country values
            month, country = Path(root).parts[-2:]
            if (month == 'yearly'):
                month = float("NaN")
            df["month"] = pd.DataFrame([month]*len(df))
            df["country"] = pd.DataFrame([country]*len(df))
            
            # reformat column names
            df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
            
            # gather list of dataframes; columns are sorted for ease of merging
            df_list.append(df.reindex(sorted(df.columns), axis=1))
            
            print(list((month, country, file)))
# Out:
# ['01', 'Denmark', 'Book1.xlsx']
# ['01', 'Egypt', 'Book1.xlsx']
# ['01', 'Ghana', 'Book1.xlsx']
# ['02', 'Denmark', 'Book1.xlsx']
# ['02', 'Egypt', 'Book1.xlsx']
# ['02', 'Ghana', 'Book1.xlsx']
# ['03', 'Denmark', 'Book1.xlsx']
# ['03', 'Egypt', 'Book1.xlsx']
# ['03', 'Ghana', 'Book1.xlsx']
# ['04', 'Denmark', 'Book1.xlsx']
# ['04', 'Egypt', 'Book1.xlsx']
# ['04', 'Ghana', 'Book1.xlsx']
# ['05', 'Denmark', 'Book1.xlsx']
# ['05', 'Egypt', 'Book1.xlsx']
# ['05', 'Ghana', 'Book1.xlsx']
# ['06', 'Denmark', 'Book1.xlsx']
# ['06', 'Egypt', 'Book1.xlsx']
# ['06', 'Ghana', 'Book1.xlsx']
# ['07', 'Denmark', 'Book1.xlsx']
# ['07', 'Egypt', 'Book1.xlsx']
# ['07', 'Ghana', 'Book1.xlsx']
# ['08', 'Denmark', 'Book1.xlsx']
# ['08', 'Egypt', 'Book1.xlsx']
# ['08', 'Ghana', 'Book1.xlsx']
# ['09', 'Denmark', 'Book1.xlsx']
# ['09', 'Egypt', 'Book1.xlsx']
# ['10', 'Denmark', 'Book1.xlsx']
# ['10', 'Egypt', 'Book1.xlsx']
# ['10', 'Ghana', 'Book1.xlsx']
# ['11', 'Denmark', 'Book1.xlsx']
# ['11', 'Egypt', 'Book1.xlsx']
# ['11', 'Ghana', 'Book1.xlsx']
# ['12', 'Denmark', 'Book1.xlsx']
# ['12', 'Egypt', 'Book1.xlsx']
# ['12', 'Ghana', 'Book1.xlsx']
# [nan, 'Denmark', 'Book1.xlsx']
# [nan, 'Egypt', 'Book1.xlsx']
# [nan, 'Ghana', 'Book1.xlsx']

# %%
data_mths = pd.concat(df_list[0:35]).reset_index(drop=True)
data_yrs = pd.concat(df_list[35:38]).reset_index(drop=True)

# %%
#data_mths.head(5)

# %%
#data_mths.info()

# %%
#data_yrs.head(5)

# %%
#data_yrs.info()

# %%
set(data_mths.columns) - set(data_yrs.columns)
# Out:
# {'del_eq_ofc', 'forward_code', 'org_eq_ofc'}

# %%
# merging data
full_data = data_mths.append(data_yrs, ignore_index=True).drop_duplicates(subset='b/l_no')

# %%
col_unique_vals = []
for i in full_data.columns:
    if isinstance(full_data[i], pd.DataFrame):
        dt = 'DF'
        nu = sum(full_data[i].nunique())
    else :
        dt = full_data[i].dtypes
        nu = full_data[i].nunique()
    ds = full_data[i].shape
    col_unique_vals.append((i, nu))
    #print("Column \'{}\' with {} unique values; \n of type {} with shape {}.".format(i, nu, dt, ds))
    print("{} COLUMN \'{}\' has [{}] unique values.".format(dt, i, nu))
    
max_nu = max([i[1] for i in col_unique_vals])
max_nu
# Out:
# int64 COLUMN 'activity_feu' has [70] unique values.
# int64 COLUMN 'activity_teu' has [63] unique values.
# object COLUMN 'also_notify_name' has [358] unique values.
# object COLUMN 'b/l_no' has [5313] unique values.
# object COLUMN 'booking_contact_e-mail' has [320] unique values.
# object COLUMN 'booking_contact_phone_number' has [328] unique values.
# object COLUMN 'booking_no' has [4891] unique values.
# object COLUMN 'cmdt' has [452] unique values.
# float64 COLUMN 'cmdt_code' has [455] unique values.
# object COLUMN 'consignee' has [1547] unique values.
# object COLUMN 'consignee_address' has [1881] unique values.
# object COLUMN 'country' has [3] unique values.
# object COLUMN 'customs_description' has [1323] unique values.
# object COLUMN 'del' has [163] unique values.
# object COLUMN 'export_name' has [441] unique values.
# float64 COLUMN 'feu' has [80] unique values.
# object COLUMN 'forward_name' has [710] unique values.
# object COLUMN 'freight_term' has [2] unique values.
# float64 COLUMN 'mea(cbm)' has [355] unique values.
# object COLUMN 'month' has [12] unique values.
# object COLUMN 'mty_p/up_cy' has [13] unique values.
# object COLUMN 'notify_address' has [2198] unique values.
# object COLUMN 'notify_name' has [1729] unique values.
# int64 COLUMN 'pkg' has [1281] unique values.
# object COLUMN 'pkg_unit' has [34] unique values.
# object COLUMN 'pod(booking)' has [132] unique values.
# object COLUMN 'pol(booking)' has [7] unique values.
# object COLUMN 'por' has [8] unique values.
# int64 COLUMN 'rep_cmdt' has [90] unique values.
# float64 COLUMN 'rev.week' has [54] unique values.
# datetime64[ns] COLUMN 'sailing_dt' has [1426] unique values.
# object COLUMN 'shipper' has [1373] unique values.
# object COLUMN 'shipper_address' has [1798] unique values.
# object COLUMN 'si_contact_e-mail' has [313] unique values.
# object COLUMN 'si_contact_phone_number' has [433] unique values.
# float64 COLUMN 'teu' has [66] unique values.
# object COLUMN 'trunk_pod' has [96] unique values.
# object COLUMN 'trunk_pol' has [11] unique values.
# object COLUMN 'trunk_vvd' has [224] unique values.
# object COLUMN 'vessel_name' has [30] unique values.
# float64 COLUMN 'wgt(kgs)' has [2523] unique values.
# object COLUMN 'del_eq_ofc' has [36] unique values.
# object COLUMN 'forward_code' has [9] unique values.
# object COLUMN 'org_eq_ofc' has [2] unique values.
# 5313

# %%
# final data exploration; b/l_no has most no. of unique values
full_data.sort_values(by='b/l_no')
# Out:
#       activity_feu  activity_teu  \
# 5637             0             2
# 5641             0             1
# 5668             0             1
# 5587             0            14
# 5642             5             0
# ...            ...           ...
# 2975             0             2
# 568              0             1
# 583              0             1
# 2390             0             4
# 5473             0             2
#
#                                        also_notify_name         b/l_no  \
# 5637      * TEL: +66 2321 7181-92\n* FAX: +66 2321 4152   AAR102100200
# 5641                                                NaN  AAR102101200W
# 5668                                                NaN   AAR102101300
# 5587                                                NaN   AAR102323700
# 5642  ** CONTAXT PERSON:\nMR. SEONG KI LEE\nTEL: +82...   AAR102389100
# ...                                                 ...            ...
# 2975  JBG LOGISTICS CO.,LTD.\nJUNG-GU,PUSAN,KOREA(05...   TEM300668200
# 568   HYPERO COMMODITIES F.Z.E.\nSM-OFFICE - E1 - 19...   TEM300669200
# 583                                                 NaN   TEM300669300
# 2390  ***TELF: +34 902 324 008/956 581 45\n3 \nEmail...   TEM300847100
# 5473                                                NaN   TEM300847200
#
#      booking_contact_e-mail booking_contact_phone_number    booking_no  \
# 5637                    NaN                          NaN  AAR102100200
# 5641                    NaN                          NaN  AAR102101200
# 5668                    NaN                          NaN  AAR102101300
# 5587                    NaN                          NaN  AAR102323700
# 5642                    NaN                          NaN  AAR102389100
# ...                     ...                          ...           ...
# 2975                    NaN                          NaN  TEM300668200
# 568                     NaN                          NaN  TEM300669200
# 583                     NaN                          NaN  TEM300669300
# 2390                    NaN                          NaN  TEM300847100
# 5473                    NaN                          NaN  TEM300847200
#
#                                                    cmdt  cmdt_code  \
# 5637  ANIMAL FEED, WHETHER OR NOT CONTAINING CHEMICA...   230002.0
# 5641                                  FIBERS YARNS; NOS   550004.0
# 5668                                 POTATO STARCH, NOS   110803.0
# 5587  ANIMAL FEED, WHETHER OR NOT CONTAINING CHEMICA...   230002.0
# 5642                                 POTATO STARCH, NOS   110803.0
# ...                                                 ...        ...
# 2975                                           ORE, NOS   260003.0
# 568                                       TEAKWOOD, NOS   440005.0
# 583                                       TEAKWOOD, NOS   440005.0
# 2390                                  STEEL PLATES, NOS   730203.0
# 5473                                      TEAKWOOD, NOS   440005.0
#
#                                               consignee  \
# 5637                           TO ORDER OF BANGKOK BANK
# 5641    DHL GLOBAL FORWARDING (CHINA) CO NANJING BRANCH
# 5668                           TO ORDER OF DBS BANK LTD
# 5587                                           TO ORDER
# 5642                              PALDO COMPANY LIMITED
# ...                                                 ...
# 2975        LIANYUNGANG PANFU IMPORT & EXPORT  CO. LTD.
# 568   LIANYUNGANG BRANDHAM TRADE CO.LTD., RM 516, NO...
# 583                                            TO ORDER
# 2390                                           TO ORDER
# 5473                                           TO ORDER
#
#                                       consignee_address  country  \
# 5637                    PUBLIC COMPANY LIMITED, BANGKOK  Denmark
# 5641  9/F, BLOCK 2, CITY GATEWAY\nM 359 MIDDLE JIANG...  Denmark
# 5668                                                NaN  Denmark
# 5587                                                NaN  Denmark
# 5642  577 GANGNAMDAERO SEOCHO-GU\nSOUTH KOREA\n+82-2...  Denmark
# ...                                                 ...      ...
# 2975  A02-104, HUADONG TOWN, XINGUANG \nROAD,E & T D...    Ghana
# 568                    CHAOYANG ROAD\nLIANYUNGANG,CHINA    Ghana
# 583                                                   .    Ghana
# 2390                                                NaN    Ghana
# 5473                                                  .    Ghana
#
#            customs_description    del         export_name  feu  \
# 5637    DANISH FISHMEAL LT-999  THLCH  354 1501011 1 1334  0.0
# 5641  TEX WATER-BLOCKING GLASS  CNNKG                 NaN  0.0
# 5668    SUPERIOR POTATO STARCH  SGSIN         EBJ35404811  0.0
# 5587        FF WHITE FISH MEAL  CNBEJ  354 1501003 1 1244  0.0
# 5642    SUPERIOR POTATO STARCH  KRKWZ         EBJ35404792  5.0
# ...                        ...    ...                 ...  ...
# 2975                  LEAD ORE  KRPUS                 NaN  0.0
# 568                   LEAD ORE  CNLYG                 NaN  0.0
# 583               AFRICAN WOOD  CNHUA                 NaN  0.0
# 2390                LEAD RAILS  ESALG                 NaN  0.0
# 5473              AFRICAN WOOD  CNNBO                 NaN  0.0
#
#                                            forward_name freight_term  \
# 5637               A. HARTRODT-DKI APS\nGROENLANDSVEJ 5            P
# 5641  DHL GLOBAL FORWARDING (DENMARK) A/S\n AALBORG\...            P
# 5668                          SCAN GLOBAL LOGISTICS A/S            P
# 5587               A. HARTRODT-DKI APS\nGROENLANDSVEJ 5            P
# 5642         SCAN GLOBAL LOGISTICS A/S\nOERESUNDSVEJ 12            P
# ...                                                 ...          ...
# 2975                                                NaN            P
# 568                                     SAME AS SHIPPER            P
# 583                                     SAME AS SHIPPER            C
# 2390                                  KAMP SHIPPING LTD            P
# 5473                                    SAME AS SHIPPER            C
#
#       mea(cbm) month mty_p/up_cy  \
# 5637       0.0    12         NaN
# 5641       0.0    12     DKAARY5
# 5668       0.0    12     DKAARY5
# 5587       0.0    12         NaN
# 5642       0.0    12     DEHAMRT
# ...        ...   ...         ...
# 2975       0.0    06     GHTEMY2
# 568        0.0    01     GHTEMY2
# 583       15.0    01     GHTEMY2
# 2390       0.0    05     GHTEMY2
# 5473      34.0    11     GHTEMY2
#
#                                          notify_address  \
# 5637  1964, 1966, 1968, 1970 ON-NUT ROAD,\nSUANLUANG...
# 5641                                                NaN
# 5668        NORTH LINK BUILDING 06-70\nSINGAPORE 757695
# 5587  1720RM, 17/F. JINXIMINGMEN\nBUILDIING. NO. 1 D...
# 5642  DOCHEOK-MYEON 401-82 BEON-GIL\nGWANGJU-SI GYEO...
# ...                                                 ...
# 2975    C-55,2ND FLOOR, PREET VIHAR\nDELHI-110092,INDIA
# 568            C-55,2ND FLOOR,PREET VIHAR\nDELHI-110092
# 583   VILLAGE XIXIANG TOWN BAOAN DISTRICT\nSHENZHEN ...
# 2390  EDIFICIO DE SERVICIOS AREA DE EL FR\nESNO, TOR...
# 5473  NANCHANG CITY, JIANGXI PROVINCE\nCHINA MOB:188...
#
#                                             notify_name    pkg pkg_unit  \
# 5637                       AMERICAN MARKETING CO., LTD.    810       BG
# 5641                                  SAME AS CONSIGNEE     20       PE
# 5668     NEWTECH MACHINERY PTE LTD\n10 ADMIRALTY STREET    810       BG
# 5587                     FUZHOU PIN GUAN TRADE CO. LTD.  12306       BG
# 5642      PALDO COMPANY LIMITED\n(GONGJAM DISTRIBUTION)    110       BG
# ...                                                 ...    ...      ...
# 2975                              SUCCESS EXIM PVT.LTD.      2       LT
# 568                               SUCCESS EXIM PVT LTD.      1       LT
# 583   SHENZHEN POLYWOOD TRADING CO LTD\nROOM 403 NO....    150       PC
# 2390  OPERINTER ANDALUCÍA SL: \nAREA LOGISTICA BAHIA...     65       BG
# 5473             HU WEI WU\n1688 HONGGUTAN NEW DISTRICT    197       PC
#
#      pod(booking) pol(booking)    por  rep_cmdt  rev.week          sailing_dt  \
# 5637        THLCH        DKAAR  DKAAR      2300      50.0 2020-12-21 21:30:00
# 5641        CNNKG        DKAAR  DKAAR      5500      51.0 2020-12-24 08:15:00
# 5668        SGSIN        DKAAR  DKAAR      1100      52.0 2020-12-28 15:40:00
# 5587        CNBEJ        DKAAR  DKAAR      2300      48.0 2020-12-04 13:00:00
# 5642        KRPUS        DKAAR  DKAAR      1100      51.0 2020-12-24 08:15:00
# ...           ...          ...    ...       ...       ...                 ...
# 2975        KRPUS        GHTEM  GHTEM      2600      24.0 2020-06-22 08:15:00
# 568         CNLYG        GHTEM  GHTEM      4400       2.0 2020-01-18 06:30:00
# 583         CNHUA        GHTEM  GHTEM      4400       2.0 2020-01-19 09:00:00
# 2390        ESALG        GHTEM  GHTEM      7300      19.0 2020-05-19 11:54:00
# 5473        CNNBO        GHTEM  GHTEM      4400      44.0 2020-11-02 06:41:00
#
#                                                 shipper  \
# 5637                                      NORSILDMEL AS
# 5641                DHL GLOBAL FORWARDING (DENMARK) A/S
# 5668                     KMC KARTOFFELMELCENTRALEN AMBA
# 5587                                      FF SKAGEN A/S
# 5642  KMC KARTOFFELMELCENTRALEN A.M.B.A. HERNING VEJ 60
# ...                                                 ...
# 2975  SUCCESS AFRICA GHANA LTD P.O. BOX AS927, VALCO...
# 568   SUCCESS AFRICA GHANA LTD P.O.BOX AS 927, VALCO...
# 583   MIKE AND MUM SHIPPING AGENCY P.O.BOX 341 COMMU...
# 2390  NON FERROUS METALS GHANA LTD C/O AL JESR SCRAP...
# 5473             WILL LOGISTICS LIMITED P.O.BOX CS 8794
#
#                                     shipper_address si_contact_e-mail  \
# 5637   KJERREIDVIKEN 16\n5141 FYLLINGSDALEN\nNORWAY               NaN
# 5641       MINERALVEJ 29\nDK-9000 AALBORG \nDENMARK               NaN
# 5668         HERNINGVEJ 60\nDK-7330 BRANDE\nDENMARK   joso@scangl.com
# 5587           HAVNEVAGTVEJ 5\n9990 SKAGEN\nDENMARK               NaN
# 5642                        DK-7330 BRANDE\nDENMARK               NaN
# ...                                             ...               ...
# 2975                          ASHIAMAN - TEMA,GHANA               NaN
# 568                           ASHAIMAN,TEMA - GHANA               NaN
# 583                                    TEMA - GHANA               NaN
# 2390  P.O. BOX 32169\nSHARJAH, UNITED ARAB EMIRATES               NaN
# 5473               TEMA - GHANA\nMOB: +233542679747               NaN
#
#      si_contact_phone_number   teu trunk_pod trunk_pol  trunk_vvd  \
# 5637                     NaN   2.0     SGSIN     DEHAM  ALNE1545E
# 5641                     NaN   1.0     CNSHA     NLRTM  HJGN6314W
# 5668              0076134487   1.0     SGSIN     NLRTM  HJGN6310W
# 5587                     NaN  14.0     CNHKG     NLRTM  ALNE1545W
# 5642                     NaN   0.0     KRPUS     NLRTM  HJGN6310E
# ...                      ...   ...       ...       ...        ...
# 2975                     NaN   2.0     KRPUS     ESALG  HYSZ1949E
# 568                      NaN   1.0     CNTAO     ESALG  HYSZ1955E
# 583                      NaN   1.0     CNYIT     ESALG  HYSZ1955E
# 2390                     NaN   4.0     ESALG     GHTEM  HYSZ1951E
# 5473                     NaN   2.0     SGSIN     ESALG  HYGO1910W
#
#              vessel_name  wgt(kgs) del_eq_ofc forward_code org_eq_ofc
# 5637          WES AMELIE   46100.0        NaN          NaN        NaN
# 5641               CERES   17538.0        NaN          NaN        NaN
# 5668               CERES   21148.0        NaN          NaN        NaN
# 5587          WES AMELIE  312120.0        NaN          NaN        NaN
# 5642              CONDOR  110220.0        NaN          NaN        NaN
# ...                  ...       ...        ...          ...        ...
# 2975     INDUSTRIAL DART   51060.0        NaN          NaN        NaN
# 568   HYUNDAI VERSAILLES   24320.0        NaN          NaN        NaN
# 583   HYUNDAI VERSAILLES   23500.0        NaN          NaN        NaN
# 2390     INDUSTRIAL DART   97440.0        NaN          NaN        NaN
# 5473      IRENES RAINBOW   46000.0        NaN          NaN        NaN
#
# [5313 rows x 44 columns]

# %%
full_data = full_data.sort_values(by='sailing_dt')

# %%
# create 'aggregate' folder for the output
aggregate_path = os.path.join(os.getcwd(), 'aggregate')

try:
    os.mkdir(aggregate_path)
except OSError:
    print("Creation of the directory %s failed" % aggregate_path)
else:
    print("Successfully created the directory %s " % aggregate_path)
# Out:
# Creation of the directory C:\Users\bened\Documents\UNIVERSITY\Postgraduate & Academic Opportunities\Professional Opportunities\CDGGroup\aggregate failed

# %%
full_data[full_data['country']=='Egypt']
# Out:
# (3944, 44)

# %%
#for i in full_data['country'].unique():
#    c_df = full_data[full_data['country']==i]
#        for j in full_data['sailing_dt'].dt.year.unique()
#            y_df = full_data[full_data['sailing_dt']==j]

# %%
for i in full_data['country'].unique():
    country_path = os.path.join(aggregate_path, i)
    c_df = full_data[full_data['country']==i]
    new_path = str("aggregate" + "/" + i + "/" + "Book2.csv")
    
    try:
        os.mkdir(country_path)
    except OSError:
        print("Creation of the directory %s failed" % country_path)
    else:
        print("Successfully created the directory %s " % country_path)
    
    c_df.to_csv(new_path, index=False)
# Out:
# Creation of the directory C:\Users\bened\Documents\UNIVERSITY\Postgraduate & Academic Opportunities\Professional Opportunities\CDGGroup\aggregate\Egypt failed
# Creation of the directory C:\Users\bened\Documents\UNIVERSITY\Postgraduate & Academic Opportunities\Professional Opportunities\CDGGroup\aggregate\Denmark failed
# Creation of the directory C:\Users\bened\Documents\UNIVERSITY\Postgraduate & Academic Opportunities\Professional Opportunities\CDGGroup\aggregate\Ghana failed
